# %% [markdown]
# <a href="https://colab.research.google.com/github/marcocintra/doutorado/blob/main/TEC_Time_Series_Analysis_and_Forecast_(LSTM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #"IAGA2002_provisory2021/coi20210101dmin.min"

# %%
import pandas as pd

#wetransfer-b6cd72/IAGA2002_provisory2021/coi20210101dmin.min
# !gdown --id 1NLj9xSA_UbjquERBc_vIHwKvB2vLqjyh

df = pd.read_csv('/content/coi20210101dmin.min', delim_whitespace=True, parse_dates=True, skiprows=19)
DATE = df['DATE'][0]
#print(DATE)
TIME = df['TIME']
#print(TIME)
COIX = df['COIX']
#print(COIX)
COIY = df['COIY']
#print(COIY)
COIZ = df['COIZ']
#print(COIZ)
COIF = df['COIF']
#print(COIF)


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIX, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X COIX")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("COIX")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIY, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X COIY")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("COIY")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIZ, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X COIZ")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("COIZ")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIF, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X COIF")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("COIF")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NLj9xSA_UbjquERBc_vIHwKvB2vLqjyh
# To: /content/coi20210101dmin.min
# 100% 105k/105k [00:00<00:00, 72.4MB/s]

# %% [markdown]
# #"IAGA2002_provisory2021/coi20210110dmin.min"

# %%
import pandas as pd

#wetransfer-b6cd72/IAGA2002_provisory2021/coi20210110dmin.min
# !gdown --id 1wBhFsmUtJc4XfvHHqi4dglVJs1nSes9M

df = pd.read_csv('/content/coi20210110dmin.min', delim_whitespace=True, parse_dates=True, skiprows=19)
DATE = df['DATE'][0]
#print(DATE)
TIME = df['TIME']
#print(TIME)
COIX = df['COIX']
#print(COIX)
COIY = df['COIY']
#print(COIY)
COIZ = df['COIZ']
#print(COIZ)
COIF = df['COIF']
#print(COIF)


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIX, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/10) X COIX")
plt.xlabel("TIME (AT 2021/01/10)")
plt.ylabel("COIX")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIY, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/10) X COIY")
plt.xlabel("TIME (AT 2021/01/10)")
plt.ylabel("COIY")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIZ, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/10) X COIZ")
plt.xlabel("TIME (AT 2021/01/10)")
plt.ylabel("COIZ")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIF, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/10) X COIF")
plt.xlabel("TIME (AT 2021/01/10)")
plt.ylabel("COIF")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wBhFsmUtJc4XfvHHqi4dglVJs1nSes9M
# To: /content/coi20210110dmin.min
# 100% 105k/105k [00:00<00:00, 39.2MB/s]

# %% [markdown]
# #"IAGA2002_provisory2021/coi20210120dmin.min"

# %%
import pandas as pd

#wetransfer-b6cd72/IAGA2002_provisory2021/coi20210120dmin.min
# !gdown --id 1dYTkpqbMMbE0b2-ZQH1fHevYoGiZgtEK

df = pd.read_csv('/content/coi20210120dmin.min', delim_whitespace=True, parse_dates=True, skiprows=19)
DATE = df['DATE'][0]
#print(DATE)
TIME = df['TIME']
#print(TIME)
COIX = df['COIX']
#print(COIX)
COIY = df['COIY']
#print(COIY)
COIZ = df['COIZ']
#print(COIZ)
COIF = df['COIF']
#print(COIF)


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIX, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/20) X COIX")
plt.xlabel("TIME (AT 2021/01/20)")
plt.ylabel("COIX")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIY, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/20) X COIY")
plt.xlabel("TIME (AT 2021/01/20)")
plt.ylabel("COIY")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIZ, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/20) X COIZ")
plt.xlabel("TIME (AT 2021/01/20)")
plt.ylabel("COIZ")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIF, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/20) X COIF")
plt.xlabel("TIME (AT 2021/01/20)")
plt.ylabel("COIF")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dYTkpqbMMbE0b2-ZQH1fHevYoGiZgtEK
# To: /content/coi20210120dmin.min
# 100% 105k/105k [00:00<00:00, 38.4MB/s]

# %% [markdown]
# #"IAGA2002_provisory2021/coi20210131dmin.min"

# %%
import pandas as pd

#wetransfer-b6cd72/IAGA2002_provisory2021/coi20210131dmin.min
# !gdown --id 1RAOkxqJHT8zHy36KXbMX8ADPJEbpPCDf

df = pd.read_csv('/content/coi20210131dmin.min', delim_whitespace=True, parse_dates=True, skiprows=19)

DATE = df['DATE'][0]
#print(DATE)
TIME = df['TIME']
#print(TIME)
COIX = df['COIX']
#print(COIX)
COIY = df['COIY']
#print(COIY)
COIZ = df['COIZ']
#print(COIZ)
COIF = df['COIF']
#print(COIF)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIX, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/31) X COIX")
plt.xlabel("TIME (AT 2021/01/31)")
plt.ylabel("COIX")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIY, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/31) X COIY")
plt.xlabel("TIME (AT 2021/01/31)")
plt.ylabel("COIY")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIZ, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/31) X COIZ")
plt.xlabel("TIME (AT 2021/01/31)")
plt.ylabel("COIZ")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, COIF, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/31) X COIF")
plt.xlabel("TIME (AT 2021/01/31)")
plt.ylabel("COIF")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1RAOkxqJHT8zHy36KXbMX8ADPJEbpPCDf
# To: /content/coi20210131dmin.min
# 100% 105k/105k [00:00<00:00, 36.9MB/s]

# %% [markdown]
# #"COImagHDZFvariometer2021/Jan0121.COI"

# %%
import pandas as pd

#wetransfer-b6cd72/IAGA2002_provisory2021/Jan0121.COI
# !gdown --id 1eAiqozzmOKspdI1G4DKhQBPXgJo6P4S9

df = pd.read_csv('/content/Jan0121.COI', delim_whitespace=True)

TIME = (pd.to_datetime(df['hh'].astype(str) + ':' + df['mm'].astype(str), format='%H:%M')
          .dt.time)


#df['hh'] = pd.to_datetime(df['hh'], format='%H')
#df['mm'] = pd.to_datetime(df['mm'], format='%M')
#print(df['hh'])
#print(df['mm'])

H = df['H']
#print(H)
D = df['D']
#print(D)
Z = df['Z']
#print(Z)
F = df['F']
#print(F)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MaxNLocator(4))

pd.plotting.register_matplotlib_converters()

plt.plot(TIME, H, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X H")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("H")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, D, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X D")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("D")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, Z, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X Z")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("Z")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, F, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X F")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("F")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1eAiqozzmOKspdI1G4DKhQBPXgJo6P4S9
# To: /content/Jan0121.COI
# 100% 62.0k/62.0k [00:00<00:00, 101kB/s]

# %% [markdown]
# #"COImagHDZFvariometer2021/Jan1021.COI"

# %%
import pandas as pd

#wetransfer-b6cd72/IAGA2002_provisory2021/Jan1021.COI
# !gdown --id 1KOfAIHiphSVf9WuToKkBXvUymMd-0Q31

df = pd.read_csv('/content/Jan1021.COI', delim_whitespace=True)

TIME = (pd.to_datetime(df['hh'].astype(str) + ':' + df['mm'].astype(str), format='%H:%M')
          .dt.time)


#df['hh'] = pd.to_datetime(df['hh'], format='%H')
#df['mm'] = pd.to_datetime(df['mm'], format='%M')
#print(df['hh'])
#print(df['mm'])

H = df['H']
#print(H)
D = df['D']
#print(D)
Z = df['Z']
#print(Z)
F = df['F']
#print(F)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MaxNLocator(4))

pd.plotting.register_matplotlib_converters()

plt.plot(TIME, H, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/10/01) X H")
plt.xlabel("TIME (AT 2021/10/01)")
plt.ylabel("H")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, D, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/10/01) X D")
plt.xlabel("TIME (AT 2021/10/01)")
plt.ylabel("D")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, Z, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/10/01) X Z")
plt.xlabel("TIME (AT 2021/10/01)")
plt.ylabel("Z")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, F, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/10/01) X F")
plt.xlabel("TIME (AT 2021/10/01)")
plt.ylabel("F")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KOfAIHiphSVf9WuToKkBXvUymMd-0Q31
# To: /content/Jan1021.COI
# 100% 62.0k/62.0k [00:00<00:00, 93.2MB/s]

# %% [markdown]
# #"COImagHDZFvariometer2021/Jan2021.COI"

# %%
import pandas as pd

#wetransfer-b6cd72/IAGA2002_provisory2021/Jan2021.COI
# !gdown --id 15bJFT5pbw8IKAAmwT7t_4SD3MtApZw8l

df = pd.read_csv('/content/Jan2021.COI', delim_whitespace=True)

TIME = (pd.to_datetime(df['hh'].astype(str) + ':' + df['mm'].astype(str), format='%H:%M')
          .dt.time)


#df['hh'] = pd.to_datetime(df['hh'], format='%H')
#df['mm'] = pd.to_datetime(df['mm'], format='%M')
#print(df['hh'])
#print(df['mm'])

H = df['H']
#print(H)
D = df['D']
#print(D)
Z = df['Z']
#print(Z)
F = df['F']
#print(F)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MaxNLocator(4))

pd.plotting.register_matplotlib_converters()

plt.plot(TIME, H, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/20/01) X H")
plt.xlabel("TIME (AT 2021/20/01)")
plt.ylabel("H")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, D, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/20/01) X D")
plt.xlabel("TIME (AT 2021/20/01)")
plt.ylabel("D")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, Z, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/20/01) X Z")
plt.xlabel("TIME (AT 2021/20/01)")
plt.ylabel("Z")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, F, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/20/01) X F")
plt.xlabel("TIME (AT 2021/20/01)")
plt.ylabel("F")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15bJFT5pbw8IKAAmwT7t_4SD3MtApZw8l
# To: /content/Jan2021.COI
# 100% 62.0k/62.0k [00:00<00:00, 57.6MB/s]

# %% [markdown]
# #"COImagHDZFvariometer2021/Jan3121.COI"

# %%
import pandas as pd

#wetransfer-b6cd72/IAGA2002_provisory2021/Jan3121.COI
# !gdown --id 1STON--KBCF8at8mrXU9A3qadQPPvwEj7

df = pd.read_csv('/content/Jan3121.COI', delim_whitespace=True)

TIME = (pd.to_datetime(df['hh'].astype(str) + ':' + df['mm'].astype(str), format='%H:%M')
          .dt.time)

H = df['H']
#print(H)
D = df['D']
#print(D)
Z = df['Z']
#print(Z)
F = df['F']
#print(F)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MaxNLocator(4))

pd.plotting.register_matplotlib_converters()

plt.plot(TIME, H, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/31/01) X H")
plt.xlabel("TIME (AT 2021/31/01)")
plt.ylabel("H")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, D, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/31/01) X D")
plt.xlabel("TIME (AT 2021/31/01)")
plt.ylabel("D")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, Z, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/31/01) X Z")
plt.xlabel("TIME (AT 2021/31/01)")
plt.ylabel("Z")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))

plt.plot(TIME, F, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/31/01) X F")
plt.xlabel("TIME (AT 2021/31/01)")
plt.ylabel("F")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1STON--KBCF8at8mrXU9A3qadQPPvwEj7
# To: /content/Jan3121.COI
# 100% 62.0k/62.0k [00:00<00:00, 54.4MB/s]

# %% [markdown]
# #"tec_jan_feb/tec_January.csv" (01/01/21, 10/01/21, 20/01/21 e 31/01/21)

# %%
import pandas as pd

#tec_jan_feb/tec_January.csv
# !gdown --id 19RXJoi-QBIkzmaZCak4f2KZ19jtlNJjZ

df = pd.read_csv('/content/tec_January.csv')

DATETIME = pd.to_datetime(df['timestamp']) 
DATE = DATETIME.dt.strftime('%Y-%m-%d')
VTEC = df['vtec']

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))
pd.plotting.register_matplotlib_converters()

plt.plot(DATE, VTEC, linewidth = 0.3, color='black')
plt.title("DATE X VTEC")
plt.xlabel("DATE")
plt.ylabel("VTEC")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))
pd.plotting.register_matplotlib_converters()

NOVO = df
NOVO = NOVO.set_index(NOVO['timestamp'])
NOVO = NOVO.loc['2021-01-01 00:00:00':'2021-01-01 23:59:59']
DATETIMENOVO = pd.to_datetime(NOVO['timestamp']) 
DATENOVO = DATETIMENOVO.dt.strftime('%Y-%m-%d')
VTECNOVO = NOVO['vtec']
#print(len(VTECNOVO))
#print(len(DATETIMENOVO.dt.time))

plt.plot(DATETIMENOVO.dt.time, VTECNOVO, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/01) X VTEC")
plt.xlabel("TIME (AT 2021/01/01)")
plt.ylabel("VTEC")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))
pd.plotting.register_matplotlib_converters()

NOVO = df
NOVO = NOVO.set_index(NOVO['timestamp'])
NOVO = NOVO.loc['2021-01-10 00:00:00':'2021-01-10 23:59:59']
DATETIMENOVO = pd.to_datetime(NOVO['timestamp']) 
DATENOVO = DATETIMENOVO.dt.strftime('%Y-%m-%d')
VTECNOVO = NOVO['vtec']

plt.plot(DATETIMENOVO.dt.time, VTECNOVO, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/10) X VTEC")
plt.xlabel("TIME (AT 2021/01/10)")
plt.ylabel("VTEC")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))
pd.plotting.register_matplotlib_converters()

NOVO = df
NOVO = NOVO.set_index(NOVO['timestamp'])
NOVO = NOVO.loc['2021-01-20 00:00:00':'2021-01-20 23:59:59']
DATETIMENOVO = pd.to_datetime(NOVO['timestamp']) 
DATENOVO = DATETIMENOVO.dt.strftime('%Y-%m-%d')
VTECNOVO = NOVO['vtec']

plt.plot(DATETIMENOVO.dt.time, VTECNOVO, linewidth = 0.3, color='black')
plt.title("TIME (AT 2021/01/20) X VTEC")
plt.xlabel("TIME (AT 2021/01/20)")
plt.ylabel("VTEC")
plt.show()
plt.close()

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(4))
pd.plotting.register_matplotlib_converters()

NOVO = df
NOVO = NOVO.set_index(NOVO['timestamp'])
NOVO = NOVO.loc['2021-01-31 00:00:00':'2021-01-31 23:59:59']
DATETIMENOVO = pd.to_datetime(NOVO['timestamp']) 
DATENOVO = DATETIMENOVO.dt.strftime('%Y-%m-%d')
VTECNOVO = NOVO['vtec']

plt.plot(DATETIMENOVO.dt.time, VTECNOVO, linewidth = 0.3, color='black')
print(len(VTECNOVO))
plt.title("TIME (AT 2021/01/31) X VTEC")
plt.xlabel("TIME (AT 2021/01/31)")
plt.ylabel("VTEC")
plt.show()
plt.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19RXJoi-QBIkzmaZCak4f2KZ19jtlNJjZ
# To: /content/tec_January.csv
# 100% 1.74M/1.74M [00:00<00:00, 54.8MB/s]
# 1440

# %% [markdown]
# # KERAS/LSTM USANDO DADOS DE "IAGA2002_provisory2021/coi20210101dmin.min"

# %%
#wetransfer-b6cd72/IAGA2002_provisory2021/coi20210101dmin.min
# !gdown --id 1NLj9xSA_UbjquERBc_vIHwKvB2vLqjyh
import pandas as pd
from datetime import datetime
df = pd.read_csv('/content/coi20210101dmin.min', delim_whitespace=True, parse_dates=True, skiprows=19)

#print(df.columns)
df['DATE'] = df['DATE'] + " " + df['TIME']
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y-%m-%d %H:%M:%S.%f')

#df.loc[:,'DATE'] = pd.to_datetime(df.DATE.astype(str)+' '+df.TIME.astype(str))
#df['DATE'] = pd.to_datetime(df['DATE'].apply(str)+' '+df['TIME'])
del df['TIME']
del df['|']
del df['DOY']
#df = df.set_index('DATE')
#df.index = pd.to_datetime(df.index)


DATE = df['DATE']
#print(DATE)
#TIME = df['TIME']
#print(TIME)
COIX = df['COIX']
COIX = COIX.to_numpy()
#print(type(COIX))
#print(COIX)
COIY = df['COIY']
COIY = COIY.to_numpy()
#print(COIY)
COIZ = df['COIZ']
COIZ= COIZ.to_numpy()
#print(COIZ)
COIF = df['COIF']
COIF= COIF.to_numpy()
#print(COIF)

import numpy as np
import time
# starting time
start = time.time()
# program body starts
data = df['COIX'].values
#print(data)
#print(len(data))
#print(np.shape(data))
import array
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
data = data.reshape(-1,1)
data = scaler.fit_transform(data)

plt.plot(data, 'b--', color='brown')
plt.title('DADOS NORMALIZADOS')
plt.xlabel('TIME (AT 2021/01/01)')
plt.ylabel('AMPLITUDE NORMALIZADA')
plt.show()

# definindo as amostras de treinamento e teste segundo o hold-out.
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]
print(len(train), len(test))

# conversão da série temporal em uma matriz de atributos para regressão
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
 
 # Atributos X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

df=pandas.DataFrame(data)
df.head()

# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2)

# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(data)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(data)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(data)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(data))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# program body ends
# end time
end = time.time()
print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))
print(f"Runtime of the program is {end - start} seconds")

print('Summary')
print(model.summary())
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NLj9xSA_UbjquERBc_vIHwKvB2vLqjyh
# To: /content/coi20210101dmin.min
# 100% 105k/105k [00:00<00:00, 92.9MB/s]
# 964 476
# Epoch 1/50
# 962/962 - 3s - loss: 0.0660
# Epoch 2/50
# 962/962 - 2s - loss: 0.0072
# Epoch 3/50
# 962/962 - 2s - loss: 0.0028
# Epoch 4/50
# 962/962 - 2s - loss: 5.5901e-04
# Epoch 5/50
# 962/962 - 2s - loss: 1.3183e-04
# Epoch 6/50
# 962/962 - 2s - loss: 1.0983e-04
# Epoch 7/50
# 962/962 - 2s - loss: 1.1237e-04
# Epoch 8/50
# 962/962 - 2s - loss: 1.1358e-04
# Epoch 9/50
# 962/962 - 2s - loss: 1.1457e-04
# Epoch 10/50
# 962/962 - 2s - loss: 1.1837e-04
# Epoch 11/50
# 962/962 - 2s - loss: 1.1333e-04
# Epoch 12/50
# 962/962 - 2s - loss: 1.1417e-04
# Epoch 13/50
# 962/962 - 2s - loss: 1.0991e-04
# Epoch 14/50
# 962/962 - 2s - loss: 1.0831e-04
# Epoch 15/50
# 962/962 - 2s - loss: 1.1058e-04
# Epoch 16/50
# 962/962 - 2s - loss: 1.0880e-04
# Epoch 17/50
# 962/962 - 2s - loss: 1.0683e-04
# Epoch 18/50
# ...
